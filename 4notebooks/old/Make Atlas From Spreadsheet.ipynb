# %%
import sys

sys.path.insert(0,'/global/project/projectdirs/metatlas/anaconda/lib/python2.7/site-packages' )
from metatlas import metatlas_objects as metob

import qgrid
import pandas as pd
# %matplotlib notebook


# df = pd.read_csv('/global/homes/b/bpb/notebooks/MetAtlas_Workflow_20151116/five things for metatlas2/201500826_library_qxqct_hilic_pos.txt', sep='\t') #if you are loading the corrected names
# df = pd.read_csv('/global/homes/b/bpb/notebooks/MetAtlas_Workflow_20151116/five things for metatlas2/201500826_library_qxqct_hilic_neg.txt', sep='\t') #if you are loading the corrected names
# df = pd.read_csv('/global/homes/b/bpb/notebooks/atlas_finfo_to_be_loaded/20151130_Atlas_POS_HILIC_LS_Validated (1).csv',sep = ',')
# df = pd.read_csv('/global/homes/b/bpb/notebooks/atlas_finfo_to_be_loaded/20151130_Atlas_NEG_HILIC_LS_Validated.csv',sep = ',')
# df = pd.read_csv('/global/homes/b/bpb/notebooks/atlas_finfo_to_be_loaded/20151130_Atlas_POS_HILIC_LS_ISTDs.csv',sep = ',')
# df = pd.read_csv('/global/homes/b/bpb/notebooks/atlas_finfo_to_be_loaded/20151130_Atlas_NEG_HILIC_LS_ISTDs.csv',sep = ',')
# df = pd.read_csv('/global/homes/b/bpb/notebooks/atlas_finfo_to_be_loaded/HMArkin_Pos_Atlas v3 MCNames (1).txt',sep = '\t')
# df = pd.read_csv('../atlas_finfo_to_be_loaded/20151208_Atlas_POS_HILIC_LS_Validated_RTcorr.csv',sep = ',')
df = pd.read_csv('../atlas_finfo_to_be_loaded/VIOLACEIN ATLAS update 20160126_plant.txt',sep = '\t')

df.columns = [x.lower() for x in df.columns]
qgrid.show_grid(df, precision=5)

# TODO: Make one Atlas.  
# TODO: Add column labels for each mzref, rtref, and fragmentation_ref
# TODO: Make template for this
# TODO: Make error checker to ensure Adduct is conforming to specification
# TODO: make error checker to ensure modification is conforming to specification

# %%
df
# Out:
#     rt_peak  rt_min  rt_max                              name
# 0      4.30    4.20    4.50                         violacein
# 1      4.80    4.70    4.90                    deoxyviolacein
# 2      4.66    4.60    4.70                    deoxyviolacein
# 3      3.68    3.60    3.75                      proviolacein
# 4      4.05    3.80    4.20                 prodeoxyviolacein
# 5      4.11    4.05    4.20            protodeoxyviolaceinate
# 6      4.59    4.50    4.62            protodeoxyviolaceinate
# 7      4.67    4.62    4.80            protodeoxyviolaceinate
# 8      4.17    4.10    4.22                 deoxyviolaceinate
# 9      4.28    4.22    4.40                 deoxyviolaceinate
# 10     3.88    3.80    4.00                 protoviolaceinate
# 11     3.71    3.64    3.80                      violaceinate
# 12     2.36    2.25    2.50                    |D-tryptophan|
# 13     3.05    2.90    3.20  2-imino-3-(indol-3-yl)propanoate
# 14     3.60    3.50    3.70                   chromopyrrolate
# 15     3.80    3.70    3.90                   chromopyrrolate
# 16     3.96    3.90    4.00                   chromopyrrolate
# 17     4.18    4.10    4.25                   chromopyrrolate

# %%
for c in metob.retrieve('Atlas',name='%_LS_%'):
    print c.name
# 2-acetamido-2-deoxy-beta-D-glucopyranosyl-(1->4)-2-amino-2-deoxy-D-glucopyranose Cite this Record
# Out:
# 20151130_LS_Negative_Hilic_QExactive_Archetypes

# %%
# compounds that have the wrong compound name will be listed
# Keep running this until no more compounds are listed
for x in df.index:
    if not metob.retrieve('Compounds',name=df.name[x]):
        print df.name[x], "is not in database"

# %%
df.to_csv('saveit.tab', sep='\t')

# %%
myCompounds = []
rt_min = []
rt_max = []
rt_peak = []
mz = []
mz_tolerance = []
for x in df.index:
    c = metob.retrieve('Compounds',name=df.name[x])[0] #currently, all copies of the molecule are returned.  The 0 is the most recent one. 
    #TODO: Consider possible change to make thinkgs like compound should be immutable and not behave this way
    myCompounds.append(c)
    rt_min.append(df.rt_min[x])
    rt_max.append(df.rt_max[x])
    rt_peak.append(df.rt_peak[x])
#     mz.append(df.mz[x])
    mz.append(c.mono_isotopic_molecular_weight + 1.007276)

#     mz_tolerance.append(df.mz_threshold[x])
#     dmz = 1e6 * (c.mono_isotopic_molecular_weight + 1.007276 - df.mz[x] ) / ( df.mz[x])
#     if abs(dmz) > 100:
#         dmz = 1e6 * (c.MonoIsotopic_molecular_weight + 59.013851 - df.mz[x] ) / df.mz[x]
#         print c.MonoIsotopic_molecular_weight - df.mz[x]
        
#     print '%5.2f'%abs(dmz), "\t", c.name,c.formula,c.mono_isotopic_molecular_weight,c.description, df.rt_min[x], df.rt_max[x], df.mz[x]#, c.InChI  
    #TODO: See above todo's.  this block needs to be rebuilt

# %%
c
# Out:
# {'creation_time': '2015-10-08T17:36:13',
#  'description': u'',
#  'formula': u'C20H13N3O3',
#  'functional_sets': [],
#  'head_id': u'601655f8a89046409794480bf73e2a0d',
#  'inchi': u'InChI=1S/C20H13N3O3/c24-10-5-6-15-12(7-10)14(9-21-15)17-8-13(19(25)23-17)18-11-3-1-2-4-16(11)22-20(18)26/h1-9,21,24H,(H,22,26)(H,23,25)/b18-13+',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:10',
#  'mono_isotopic_molecular_weight': 343.095703125,
#  'name': u'violacein',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'601655f8a89046409794480bf73e2a0d',
#  'url': u'',
#  'username': u'bpb'}

# %%
#     myID.description = 'mz=%5.4f,ppm=%5.4f,RTmin=%5.4f,RTmax=%5.4f,RTpeak=%5.4f'%(mz[i],
#                                                                                  mz_tolerance[i],
#                                                                                  rt_min[i],
#                                                                                  rt_max[i],
#                                                                                  rt_peak[i])
#     print myID.references


all_identifications = []
for i,c in enumerate(myCompounds):
    mzRef = metob.MzReference()

    # take the mz value from the spreadsheet
    mzRef.mz = mz[i]
    
    #TODO: calculate the mz from theoretical adduct and modification if provided.
#     mzRef.mz = c.MonoIso topic_molecular_weight + 1.007276
    mzRef.mz_tolerance = 5#mz_tolerance[i]
    mzRef.mz_tolerance_units = 'ppm'
    mzRef.detected_polarity = 'positive'
#     mzRef.adduct = '[M-H]'
    
    rtRef = metob.RtReference()
    rtRef.rt_units = 'min'
    rtRef.rt_min = rt_min[i]
    rtRef.rt_max = rt_max[i]
    rtRef.rt_peak = rt_peak[i]
    
    myID = metob.CompoundIdentification()
    myID.compound = [c]
    myID.mz_references = [mzRef]
    myID.rt_references = [rtRef]

    all_identifications.append(myID)

myAtlas = metob.Atlas()
#metob.Atlas() has "compound_identifications" and a "name"
# myAtlas.name = '20151130_LS_Negative_Hilic_QExactive_Archetypes'
myAtlas.name = '20160126_KBL_PS_plant_violacein'
myAtlas.compound_identifications = all_identifications
metob.store(myAtlas)

# %%
myAtlas
# Out:
# {'compound_identifications': [{'compound': [{'creation_time': '2015-10-08T17:37:24',
#  'description': u'',
#  'formula': u'C8H11N3O3',
#  'functional_sets': [],
#  'head_id': u'1e9be71c13c54c078066ae74bbc19216',
#  'inchi': u'InChI=1S/C8H11N3O3/c1-5(12)11-7(8(13)14)2-6-3-9-4-10-6/h3-4,7H,2H2,1H3,(H,9,10)(H,11,12)(H,13,14)/p-1/t7-/m0/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 197.08004760742188,
#  'name': u'<i>N</i>-acetyl-L-histidine',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'1e9be71c13c54c078066ae74bbc19216',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'b92a5cfc6618492b83a9cef3ff694f94',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'40368087bcc140afba0303d7c4d4e04d',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 198.0885,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'40368087bcc140afba0303d7c4d4e04d',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'5ae11ebaad564080a8aa14cccd3a5af0',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 10.812999999999999,
#  'rt_min': 10.571,
#  'rt_peak': 10.679,
#  'rt_units': 'min',
#  'unique_id': u'5ae11ebaad564080a8aa14cccd3a5af0',
#  'username': u'bpb'}],
#  'unique_id': u'b92a5cfc6618492b83a9cef3ff694f94',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:25',
#  'description': u'',
#  'formula': u'C8H16N2O3',
#  'functional_sets': [],
#  'head_id': u'18c066be31b142688fdf6ab1cc47d74a',
#  'inchi': u'InChI=1S/C8H16N2O3/c1-6(11)10-5-3-2-4-7(9)8(12)13/h7H,2-5,9H2,1H3,(H,10,11)(H,12,13)/t7-/m0/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 188.1160888671875,
#  'name': u'<i>N</i><sup>6</sup>-acetyl-L-lysine',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'18c066be31b142688fdf6ab1cc47d74a',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'bd47839fcee244bfa9ee6db399298c81',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'2482102f211b4621a7de1d9b5f33a0e3',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 189.1238,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'2482102f211b4621a7de1d9b5f33a0e3',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'e61a4ada6fde4cda82b42bcb4faa568f',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 8.857000000000001,
#  'rt_min': 8.522,
#  'rt_peak': 8.687000000000001,
#  'rt_units': 'min',
#  'unique_id': u'e61a4ada6fde4cda82b42bcb4faa568f',
#  'username': u'bpb'}],
#  'unique_id': u'bd47839fcee244bfa9ee6db399298c81',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:36:21',
#  'description': u'',
#  'formula': u'C11H15N5O3S',
#  'functional_sets': [],
#  'head_id': u'24cee909b28945cc98d3e0b3b9b03123',
#  'inchi': u'InChI=1S/C11H15N5O3S/c1-20-2-5-7(17)8(18)11(19-5)16-4-15-6-9(12)13-3-14-10(6)16/h3-5,7-8,11,17-18H,2H2,1H3,(H2,12,13,14)/t5-,7-,8-,11-/m1/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:11',
#  'mono_isotopic_molecular_weight': 297.0895690917969,
#  'name': u"<i>S</i>-methyl-5'-thioadenosine",
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'24cee909b28945cc98d3e0b3b9b03123',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'd645decb4c444e12b8ed02890468f70a',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'920430cd460849899ae89fe8a840596a',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 298.0978,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'920430cd460849899ae89fe8a840596a',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'46ebcdf6d5b84d939a65920814c36c16',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 3.6239999999999997,
#  'rt_min': 3.165,
#  'rt_peak': 3.3310000000000004,
#  'rt_units': 'min',
#  'unique_id': u'46ebcdf6d5b84d939a65920814c36c16',
#  'username': u'bpb'}],
#  'unique_id': u'd645decb4c444e12b8ed02890468f70a',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:25',
#  'description': u'',
#  'formula': u'C8H20NO6P',
#  'functional_sets': [],
#  'head_id': u'394fd02935a646b189d9d6acdde02779',
#  'inchi': u'InChI=1S/C8H20NO6P/c1-9(2,3)4-5-14-16(12,13)15-7-8(11)6-10/h8,10-11H,4-7H2,1-3H3/t8-/m1/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 257.1028137207031,
#  'name': u'<i>sn</i>-glycero-3-phosphocholine',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'394fd02935a646b189d9d6acdde02779',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'66f91117d59449fda5025d8515597a42',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'f331e443df2e486e82a2fd662e67d36a',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 258.1106,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'f331e443df2e486e82a2fd662e67d36a',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'ba972e42d1e144838d6f837cc090438b',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 12.389000000000001,
#  'rt_min': 12.206,
#  'rt_peak': 12.356,
#  'rt_units': 'min',
#  'unique_id': u'ba972e42d1e144838d6f837cc090438b',
#  'username': u'bpb'}],
#  'unique_id': u'66f91117d59449fda5025d8515597a42',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:25',
#  'description': u'',
#  'formula': u'C5H9NO3',
#  'functional_sets': [],
#  'head_id': u'21adf68b4f2a4668a9f4c34fcf57452d',
#  'inchi': u'InChI=1S/C5H9NO3/c7-3-1-4(5(8)9)6-2-3/h3-4,6-7H,1-2H2,(H,8,9)/t3-,4+/m1/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 131.05824279785156,
#  'name': u'<i>trans</i>-4-hydroxy-L-proline',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'21adf68b4f2a4668a9f4c34fcf57452d',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'99321758c603444d9c3fac0aa003ca57',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'8ea1280e0f274c168eac02dd27094509',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 132.0663,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'8ea1280e0f274c168eac02dd27094509',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'3b8ce778c49c4c96ab90e5a72068b9da',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 12.03,
#  'rt_min': 11.764000000000001,
#  'rt_peak': 11.955,
#  'rt_units': 'min',
#  'unique_id': u'3b8ce778c49c4c96ab90e5a72068b9da',
#  'username': u'bpb'}],
#  'unique_id': u'99321758c603444d9c3fac0aa003ca57',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:13',
#  'description': u'',
#  'formula': u'C9H8O2',
#  'functional_sets': [],
#  'head_id': u'0794f55029de42648179872fb8964f91',
#  'inchi': u'InChI=1S/C9H8O2/c10-9(11)7-6-8-4-2-1-3-5-8/h1-7H,(H,10,11)/p-1/b7-6+',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:12',
#  'mono_isotopic_molecular_weight': 148.05242919921875,
#  'name': u'<i>trans</i>-cinnamate',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'0794f55029de42648179872fb8964f91',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'bb9783fe9f6947aab2a9d40739da9879',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'5b1d3a30a2d446978344f0da42f75a37',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 149.0595,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'5b1d3a30a2d446978344f0da42f75a37',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'864f9e51441941ab91126e2f6911304a',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 8.64,
#  'rt_min': 8.286,
#  'rt_peak': 8.402999999999999,
#  'rt_units': 'min',
#  'unique_id': u'864f9e51441941ab91126e2f6911304a',
#  'username': u'bpb'}],
#  'unique_id': u'bb9783fe9f6947aab2a9d40739da9879',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:14',
#  'description': u'',
#  'formula': u'C9H13N3O5',
#  'functional_sets': [],
#  'head_id': u'da71f712acca4b6ba62075a967d43c40',
#  'inchi': u'InChI=1S/C9H13N3O5/c10-5-1-2-12(9(16)11-5)8-7(15)6(14)4(3-13)17-8/h1-2,4,6-8,13-15H,3H2,(H2,10,11,16)/t4-,6-,7-,8-/m1/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:12',
#  'mono_isotopic_molecular_weight': 243.0855255126953,
#  'name': u'|cytidine|',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'da71f712acca4b6ba62075a967d43c40',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'32a7ee215b0b478882d63c9fd3af44c1',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'14463b1d687b4ee7af8b5c9457c1e7e9',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 244.0933,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'14463b1d687b4ee7af8b5c9457c1e7e9',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'ee4322d14a3c40d18ff686836cbc9716',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 8.986,
#  'rt_min': 8.527999999999999,
#  'rt_peak': 8.745,
#  'rt_units': 'min',
#  'unique_id': u'ee4322d14a3c40d18ff686836cbc9716',
#  'username': u'bpb'}],
#  'unique_id': u'32a7ee215b0b478882d63c9fd3af44c1',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:14',
#  'description': u'',
#  'formula': u'C4H5N3O',
#  'functional_sets': [],
#  'head_id': u'd30e3894050e494a8f7b18ae8e70cf25',
#  'inchi': u'InChI=1S/C4H5N3O/c5-3-1-2-6-4(8)7-3/h1-2H,(H3,5,6,7,8)',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:12',
#  'mono_isotopic_molecular_weight': 111.04325866699219,
#  'name': u'|cytosine|',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'd30e3894050e494a8f7b18ae8e70cf25',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'9db525ba18404838883ba55f1df969f4',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'babda1689b4d4cb9933bed68bff87f08',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 112.0506,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'babda1689b4d4cb9933bed68bff87f08',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'18ed8bbfd652483c878cb59d37051b42',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 7.593999999999999,
#  'rt_min': 7.143,
#  'rt_peak': 7.36,
#  'rt_units': 'min',
#  'unique_id': u'18ed8bbfd652483c878cb59d37051b42',
#  'username': u'bpb'}],
#  'unique_id': u'9db525ba18404838883ba55f1df969f4',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:24',
#  'description': u'',
#  'formula': u'C5H10N2O3',
#  'functional_sets': [],
#  'head_id': u'e799905512a144bebdbf103908665efe',
#  'inchi': u'InChI=1S/C5H10N2O3/c6-3(5(9)10)1-2-4(7)8/h3H,1-2,6H2,(H2,7,8)(H,9,10)/t3-/m0/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 146.0691375732422,
#  'name': u'|L-glutamine|',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'e799905512a144bebdbf103908665efe',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'0817b13008ec4db29914512cea33c89e',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'd90221189fa24a2ea4c8551dd275b0ea',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 147.0767,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'd90221189fa24a2ea4c8551dd275b0ea',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'45181e42b294454099c85f479733c1f3',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 13.194,
#  'rt_min': 12.856,
#  'rt_peak': 13.065,
#  'rt_units': 'min',
#  'unique_id': u'45181e42b294454099c85f479733c1f3',
#  'username': u'bpb'}],
#  'unique_id': u'0817b13008ec4db29914512cea33c89e',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:24',
#  'description': u'',
#  'formula': u'C6H9N3O2',
#  'functional_sets': [],
#  'head_id': u'0a725b591ef14763b2d7a7d6c0ef97d5',
#  'inchi': u'InChI=1S/C6H9N3O2/c7-5(6(10)11)1-4-2-8-3-9-4/h2-3,5H,1,7H2,(H,8,9)(H,10,11)/t5-/m0/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 155.06947326660156,
#  'name': u'|L-histidine|',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'0a725b591ef14763b2d7a7d6c0ef97d5',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'53d8bb6634bc446485947fbc7acded06',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'750e6ba7a004495c9f8dc2ad08c0ece4',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 156.0768,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'750e6ba7a004495c9f8dc2ad08c0ece4',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'b08e9889f89e490da1d32d5fda34242e',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 13.161,
#  'rt_min': 12.727,
#  'rt_peak': 12.873,
#  'rt_units': 'min',
#  'unique_id': u'b08e9889f89e490da1d32d5fda34242e',
#  'username': u'bpb'}],
#  'unique_id': u'53d8bb6634bc446485947fbc7acded06',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:24',
#  'description': u'',
#  'formula': u'C6H13NO2',
#  'functional_sets': [],
#  'head_id': u'870ba5a8c9d84f0681f5fe52a7843b49',
#  'inchi': u'InChI=1S/C6H13NO2/c1-3-4(2)5(7)6(8)9/h4-5H,3,7H2,1-2H3,(H,8,9)/t4-,5-/m0/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 131.09463500976562,
#  'name': u'|L-isoleucine|',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'870ba5a8c9d84f0681f5fe52a7843b49',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'6786b55cbd1b49ad887b4e106f89d79e',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'cb80260799c94100af9d21634f2268c6',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 132.1024,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'cb80260799c94100af9d21634f2268c6',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'52f747c5df3d43b49a1de625cad2f183',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 8.628,
#  'rt_min': 8.386000000000001,
#  'rt_peak': 8.478,
#  'rt_units': 'min',
#  'unique_id': u'52f747c5df3d43b49a1de625cad2f183',
#  'username': u'bpb'}],
#  'unique_id': u'6786b55cbd1b49ad887b4e106f89d79e',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:24',
#  'description': u'',
#  'formula': u'C6H13NO2',
#  'functional_sets': [],
#  'head_id': u'6720710f3af04ea3bf9a5085cb371955',
#  'inchi': u'InChI=1S/C6H13NO2/c1-4(2)3-5(7)6(8)9/h4-5H,3,7H2,1-2H3,(H,8,9)/t5-/m0/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 131.09463500976562,
#  'name': u'|L-leucine|',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'6720710f3af04ea3bf9a5085cb371955',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'b1a585ad73964a67b598497902d75f62',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'cab40a10b81d4beeb0d6c77245903fec',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 132.1023,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'cab40a10b81d4beeb0d6c77245903fec',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'50ea0da668b1420ea09b70f0c95d7fd3',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 9.088,
#  'rt_min': 8.628,
#  'rt_peak': 8.795,
#  'rt_units': 'min',
#  'unique_id': u'50ea0da668b1420ea09b70f0c95d7fd3',
#  'username': u'bpb'}],
#  'unique_id': u'b1a585ad73964a67b598497902d75f62',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:24',
#  'description': u'',
#  'formula': u'C3H7NO3',
#  'functional_sets': [],
#  'head_id': u'eb0ca49a95ed449aba56be106b983612',
#  'inchi': u'InChI=1S/C3H7NO3/c4-2(1-5)3(6)7/h2,5H,1,4H2,(H,6,7)/t2-/m0/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 105.04259490966797,
#  'name': u'|L-serine|',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'eb0ca49a95ed449aba56be106b983612',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'9844cdc4d88a403bb0ae4a77df7951f1',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'7bad45d08f9147e3852f3653cc96237b',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 106.05,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'7bad45d08f9147e3852f3653cc96237b',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'2d036c428d73495786f82067de88a91e',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 14.07,
#  'rt_min': 13.57,
#  'rt_peak': 13.774000000000001,
#  'rt_units': 'min',
#  'unique_id': u'2d036c428d73495786f82067de88a91e',
#  'username': u'bpb'}],
#  'unique_id': u'9844cdc4d88a403bb0ae4a77df7951f1',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:24',
#  'description': u'',
#  'formula': u'C9H11NO3',
#  'functional_sets': [],
#  'head_id': u'5512390269e44c6fae2a2098ba648bbe',
#  'inchi': u'InChI=1S/C9H11NO3/c10-8(9(12)13)5-6-1-3-7(11)4-2-6/h1-4,8,11H,5,10H2,(H,12,13)/t8-/m0/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 181.0738983154297,
#  'name': u'|L-tyrosine|',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'5512390269e44c6fae2a2098ba648bbe',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'2eb86fdac7084cd3a0e9428077eb5bbf',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'69c0f5c954694695a723965f4664e64b',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 182.0805,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'69c0f5c954694695a723965f4664e64b',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'63ba634bc9bb441188e3e0897026ad7e',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 11.305,
#  'rt_min': 11.013,
#  'rt_peak': 11.105,
#  'rt_units': 'min',
#  'unique_id': u'63ba634bc9bb441188e3e0897026ad7e',
#  'username': u'bpb'}],
#  'unique_id': u'2eb86fdac7084cd3a0e9428077eb5bbf',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:24',
#  'description': u'',
#  'formula': u'C5H11NO2',
#  'functional_sets': [],
#  'head_id': u'ccf376ccaca74d178fc79b9083cb5fc2',
#  'inchi': u'InChI=1S/C5H11NO2/c1-3(2)4(6)5(7)8/h3-4H,6H2,1-2H3,(H,7,8)/t4-/m0/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 117.0789794921875,
#  'name': u'|L-valine|',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'ccf376ccaca74d178fc79b9083cb5fc2',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'73ba4ba5c9de420f9f488db126856242',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'54ff23d8cf094b47b122ab00afa4a56b',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 118.0867,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'54ff23d8cf094b47b122ab00afa4a56b',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'7077782c696943929e7a9b58946be59f',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 10.237,
#  'rt_min': 9.743,
#  'rt_peak': 9.954,
#  'rt_units': 'min',
#  'unique_id': u'7077782c696943929e7a9b58946be59f',
#  'username': u'bpb'}],
#  'unique_id': u'73ba4ba5c9de420f9f488db126856242',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:25',
#  'description': u'',
#  'formula': u'C4H7NO2',
#  'functional_sets': [],
#  'head_id': u'e1ad4d5f064747c18c93d1f3118ad9d7',
#  'inchi': u'InChI=1S/C4H7NO2/c5-4(1-2-4)3(6)7/h1-2,5H2,(H,6,7)',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 101.04767608642578,
#  'name': u'1-aminocyclopropane-1-carboxylate',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'e1ad4d5f064747c18c93d1f3118ad9d7',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'b03fd4ed00e5424781a9cfd04044d5e0',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'fd004c50400a4cba867c2277a0bf354e',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 102.055,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'fd004c50400a4cba867c2277a0bf354e',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'bc9c5cdec76b4b249b0d0efe9bcdd30e',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 12.605,
#  'rt_min': 12.37,
#  'rt_peak': 12.456,
#  'rt_units': 'min',
#  'unique_id': u'bc9c5cdec76b4b249b0d0efe9bcdd30e',
#  'username': u'bpb'}],
#  'unique_id': u'b03fd4ed00e5424781a9cfd04044d5e0',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:36:17',
#  'description': u'',
#  'formula': u'C11H15N5O4',
#  'functional_sets': [],
#  'head_id': u'6dd7d55f320a4cc0bdc60f7793b710d7',
#  'inchi': u'InChI=1S/C11H15N5O4/c1-15-3-14-10-6(9(15)12)13-4-16(10)11-8(19)7(18)5(2-17)20-11/h3-5,7-8,11-12,17-19H,2H2,1H3',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:10',
#  'mono_isotopic_molecular_weight': 281.1123962402344,
#  'name': u'1-methyladenosine',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'6dd7d55f320a4cc0bdc60f7793b710d7',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'205ef1dd080d4baca883b298c8cc23d6',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'05512cbef0d6419a88bb91eab2375ead',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 282.1204,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'05512cbef0d6419a88bb91eab2375ead',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'52f48cadb58547f888137a2745d3178a',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 3.8560000000000003,
#  'rt_min': 3.5380000000000003,
#  'rt_peak': 3.7319999999999998,
#  'rt_units': 'min',
#  'unique_id': u'52f48cadb58547f888137a2745d3178a',
#  'username': u'bpb'}],
#  'unique_id': u'205ef1dd080d4baca883b298c8cc23d6',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:12',
#  'description': u'',
#  'formula': u'C9H8O3',
#  'functional_sets': [],
#  'head_id': u'9ba458607b004358a20d1bd1faa60119',
#  'inchi': u'InChI=1S/C9H8O3/c10-8-4-2-1-3-7(8)5-6-9(11)12/h1-6,10H,(H,11,12)/p-1/b6-5+',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:12',
#  'mono_isotopic_molecular_weight': 164.04734802246094,
#  'name': u'2-coumarate',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'9ba458607b004358a20d1bd1faa60119',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'e79fa3a958f948dd97e8e5c902ec2ba3',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'd5cedf3a659142f687f9220f13e5e901',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 165.0534,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'd5cedf3a659142f687f9220f13e5e901',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'39936bb316274ef9ad72c577831f1852',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 11.254000000000001,
#  'rt_min': 11.032,
#  'rt_peak': 11.105,
#  'rt_units': 'min',
#  'unique_id': u'39936bb316274ef9ad72c577831f1852',
#  'username': u'bpb'}],
#  'unique_id': u'e79fa3a958f948dd97e8e5c902ec2ba3',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:36:22',
#  'description': u'',
#  'formula': u'C8H9NO',
#  'functional_sets': [],
#  'head_id': u'12dac8654753432aa5d1475affbb8f87',
#  'inchi': u'InChI=1S/C8H9NO/c9-8(10)6-7-4-2-1-3-5-7/h1-5H,6H2,(H2,9,10)',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:11',
#  'mono_isotopic_molecular_weight': 135.06842041015625,
#  'name': u'2-phenylacetamide',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'12dac8654753432aa5d1475affbb8f87',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'c53a6f76324649809f586a71e3923313',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'dc3c3e76d3ea42968480cb5b4f70258a',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 136.0747,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'dc3c3e76d3ea42968480cb5b4f70258a',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'18074c029789414aa708dd8af4537945',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 10.984000000000002,
#  'rt_min': 10.788,
#  'rt_peak': 10.905,
#  'rt_units': 'min',
#  'unique_id': u'18074c029789414aa708dd8af4537945',
#  'username': u'bpb'}],
#  'unique_id': u'c53a6f76324649809f586a71e3923313',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:14',
#  'description': u'',
#  'formula': u'C10H13N5O4',
#  'functional_sets': [],
#  'head_id': u'f2d4311d7b8641fa8546a8c793f8023d',
#  'inchi': u'InChI=1S/C10H13N5O4/c11-10-13-8-7(9(18)14-10)12-3-15(8)6-1-4(17)5(2-16)19-6/h3-6,16-17H,1-2H2,(H3,11,13,14,18)/t4-,5+,6+/m0/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:12',
#  'mono_isotopic_molecular_weight': 267.09674072265625,
#  'name': u"2'-deoxyguanosine",
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'f2d4311d7b8641fa8546a8c793f8023d',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'ec7f0d22b3894d2d8b5a99fcc8181966',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'5632a2890ab540c8b54dff0ed007a2b3',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 268.1040299,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'5632a2890ab540c8b54dff0ed007a2b3',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'2da4839e958849739ac8a7bf53369c91',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 6.843,
#  'rt_min': 5.4,
#  'rt_peak': 5.692,
#  'rt_units': 'min',
#  'unique_id': u'2da4839e958849739ac8a7bf53369c91',
#  'username': u'bpb'}],
#  'unique_id': u'ec7f0d22b3894d2d8b5a99fcc8181966',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:36:13',
#  'description': u'',
#  'formula': u'C4H9NO2',
#  'functional_sets': [],
#  'head_id': u'52ce06a9225a4cfb8f4a5a6299e5be1d',
#  'inchi': u'InChI=1S/C4H9NO2/c5-3-1-2-4(6)7/h1-3,5H2,(H,6,7)',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:10',
#  'mono_isotopic_molecular_weight': 103.0633316040039,
#  'name': u'4-aminobutanoate',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'52ce06a9225a4cfb8f4a5a6299e5be1d',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'aa4a271b587f4e2fbc19173cdc0a8992',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'2ae6835e9e4e444f8b5aa3ea4239274f',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 104.0709,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'2ae6835e9e4e444f8b5aa3ea4239274f',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'6a8f15113a2242c7b63ab820b4ed4bb0',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 13.248,
#  'rt_min': 12.777000000000001,
#  'rt_peak': 12.99,
#  'rt_units': 'min',
#  'unique_id': u'6a8f15113a2242c7b63ab820b4ed4bb0',
#  'username': u'bpb'}],
#  'unique_id': u'aa4a271b587f4e2fbc19173cdc0a8992',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:36:18',
#  'description': u'',
#  'formula': u'C5H11N3O2',
#  'functional_sets': [],
#  'head_id': u'06c679ec21a9459593a5273723239ec6',
#  'inchi': u'InChI=1S/C5H11N3O2/c6-5(7)8-3-1-2-4(9)10/h1-3H2,(H,9,10)(H4,6,7,8)',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:10',
#  'mono_isotopic_molecular_weight': 145.0851287841797,
#  'name': u'4-guanidinobutanoate',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'06c679ec21a9459593a5273723239ec6',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'2fe3427fc59f456eb1293b6e6e58e9db',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'2ad9bcd8fa4d4702a0f8da8f050fbe62',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 146.0925,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'2ad9bcd8fa4d4702a0f8da8f050fbe62',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'2b6d17c788f84581a612eb10fae4fcc1',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 12.839,
#  'rt_min': 12.414000000000001,
#  'rt_peak': 12.606,
#  'rt_units': 'min',
#  'unique_id': u'2b6d17c788f84581a612eb10fae4fcc1',
#  'username': u'bpb'}],
#  'unique_id': u'2fe3427fc59f456eb1293b6e6e58e9db',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:36:20',
#  'description': u'',
#  'formula': u'C5H7NO3',
#  'functional_sets': [],
#  'head_id': u'62763b9e23f04d62861e36abe1f1f2e0',
#  'inchi': u'InChI=1S/C5H7NO3/c7-4-2-1-3(6-4)5(8)9/h3H,1-2H2,(H,6,7)(H,8,9)/p-1/t3-/m0/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:10',
#  'mono_isotopic_molecular_weight': 129.04258728027344,
#  'name': u'5-oxo-L-proline',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'62763b9e23f04d62861e36abe1f1f2e0',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'67694e0508514543adac4a25fd8d58fc',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'dc8ea7ed4bd5432282f83e136c8c9406',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 130.0502,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'dc8ea7ed4bd5432282f83e136c8c9406',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'db86d3ca6b9b41ab93e7b515083a7eac',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 10.745999999999999,
#  'rt_min': 10.285,
#  'rt_peak': 10.470999999999998,
#  'rt_units': 'min',
#  'unique_id': u'db86d3ca6b9b41ab93e7b515083a7eac',
#  'username': u'bpb'}],
#  'unique_id': u'67694e0508514543adac4a25fd8d58fc',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:36:12',
#  'description': u'',
#  'formula': u'C9H7NO',
# ...
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'bf39d5b1db914c75b4e33d100f1cff6f',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 277.1401,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'bf39d5b1db914c75b4e33d100f1cff6f',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'ed80613f5a55438f950cc2b4ca43018a',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 16.084,
#  'rt_min': 15.642000000000001,
#  'rt_peak': 15.833,
#  'rt_units': 'min',
#  'unique_id': u'ed80613f5a55438f950cc2b4ca43018a',
#  'username': u'bpb'}],
#  'unique_id': u'97f6c381cf274beeaf43fd8538c70e7a',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:24',
#  'description': u'',
#  'formula': u'C4H9NO3',
#  'functional_sets': [],
#  'head_id': u'47961d42843d4b57bbf31d9ea14889b1',
#  'inchi': u'InChI=1S/C4H9NO3/c1-2(6)3(5)4(7)8/h2-3,6H,5H2,1H3,(H,7,8)/t2-,3+/m1/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 119.05824279785156,
#  'name': u'L-threonine',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'47961d42843d4b57bbf31d9ea14889b1',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'262462f0f3e442a7a5d1a3efb023c7a1',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'10490ede74ec4b8c9cf5dd786b773e5a',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 120.0657,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'10490ede74ec4b8c9cf5dd786b773e5a',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'b9739ddb6a4f4d77839a00b25e892e27',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 12.698,
#  'rt_min': 12.222999999999999,
#  'rt_peak': 12.450999999999999,
#  'rt_units': 'min',
#  'unique_id': u'b9739ddb6a4f4d77839a00b25e892e27',
#  'username': u'bpb'}],
#  'unique_id': u'262462f0f3e442a7a5d1a3efb023c7a1',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:24',
#  'description': u'',
#  'formula': u'C11H12N2O2',
#  'functional_sets': [],
#  'head_id': u'dbe4dfe14fed4f6da11d84d344f5f581',
#  'inchi': u'InChI=1S/C11H12N2O2/c12-9(11(14)15)5-7-6-13-10-4-2-1-3-8(7)10/h1-4,6,9,13H,5,12H2,(H,14,15)/t9-/m0/s1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:13',
#  'mono_isotopic_molecular_weight': 204.08987426757812,
#  'name': u'L-tryptophan',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'dbe4dfe14fed4f6da11d84d344f5f581',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'dc3621b57d904c638c1d74f84fb242d7',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'a25c16a3fa014e268ead537ee834bbdb',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 205.0965,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'a25c16a3fa014e268ead537ee834bbdb',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'20b9dbb5302c4818b24c963bee4e7fef',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 9.695,
#  'rt_min': 9.529,
#  'rt_peak': 9.57,
#  'rt_units': 'min',
#  'unique_id': u'20b9dbb5302c4818b24c963bee4e7fef',
#  'username': u'bpb'}],
#  'unique_id': u'dc3621b57d904c638c1d74f84fb242d7',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-11-30T20:38:39',
#  'description': u'http://pubchem.ncbi.nlm.nih.gov/compound/N-Methylanthranilic_acid',
#  'formula': u'C8H9NO2',
#  'functional_sets': [],
#  'head_id': u'61e128f4fa244e4080e5374051550868',
#  'inchi': u'InChI=1S/C8H9NO2/c1-9-7-5-3-2-4-6(7)8(10)11/h2-5,9H,1H3,(H,10,11)',
#  'inchi_key': None,
#  'last_modified': '2015-11-30T20:38:49',
#  'mono_isotopic_molecular_weight': 151.063328528,
#  'name': u'N-methylanthranilic acid',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'61e128f4fa244e4080e5374051550868',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'2215844cf0e84ef59a6b4f9e00fbd6ac',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'762654179bdc4c2ba805d35e1927b269',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 152.0711,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'762654179bdc4c2ba805d35e1927b269',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'c78d3162444647c0bb530ed3bed8b6a9',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 3.641,
#  'rt_min': 3.315,
#  'rt_peak': 3.4739999999999998,
#  'rt_units': 'min',
#  'unique_id': u'c78d3162444647c0bb530ed3bed8b6a9',
#  'username': u'bpb'}],
#  'unique_id': u'2215844cf0e84ef59a6b4f9e00fbd6ac',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:10',
#  'description': u'',
#  'formula': u'C6H6N2O',
#  'functional_sets': [],
#  'head_id': u'8e0d2cfc85684471b5daa89e645d854e',
#  'inchi': u'InChI=1S/C6H6N2O/c7-6(9)5-2-1-3-8-4-5/h1-4H,(H2,7,9)',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:12',
#  'mono_isotopic_molecular_weight': 122.04801177978516,
#  'name': u'nicotinamide',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'8e0d2cfc85684471b5daa89e645d854e',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'dd6f197e17a44ba1a8b9cef8c3524f23',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'b60c972e99bb453b8725fb6cf5c7c9f6',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 123.0555,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'b60c972e99bb453b8725fb6cf5c7c9f6',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'25f5dd7fe5414789a9472861546c3d08',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 3.2319999999999998,
#  'rt_min': 3.1069999999999998,
#  'rt_peak': 3.165,
#  'rt_units': 'min',
#  'unique_id': u'25f5dd7fe5414789a9472861546c3d08',
#  'username': u'bpb'}],
#  'unique_id': u'dd6f197e17a44ba1a8b9cef8c3524f23',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:37:10',
#  'description': u'',
#  'formula': u'C6H5NO2',
#  'functional_sets': [],
#  'head_id': u'4ca085bae0a8495fa9bd0aa026ca4f8e',
#  'inchi': u'InChI=1S/C6H5NO2/c8-6(9)5-2-1-3-7-4-5/h1-4H,(H,8,9)/p-1',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:12',
#  'mono_isotopic_molecular_weight': 123.03202819824219,
#  'name': u'nicotinate',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'4ca085bae0a8495fa9bd0aa026ca4f8e',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'45dc4e13cd754790bcaf4a17450e1256',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'60d41128ec4e44b6a02a5c399e4fdcad',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 124.0393,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'60d41128ec4e44b6a02a5c399e4fdcad',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'5a2cfbfba9d24c71be4d255742046e7b',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 7.718999999999999,
#  'rt_min': 7.335,
#  'rt_peak': 7.519,
#  'rt_units': 'min',
#  'unique_id': u'5a2cfbfba9d24c71be4d255742046e7b',
#  'username': u'bpb'}],
#  'unique_id': u'45dc4e13cd754790bcaf4a17450e1256',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:36:18',
#  'description': u'',
#  'formula': u'C6H6N2O2',
#  'functional_sets': [],
#  'head_id': u'940555dd448c4cefaf88bd27560a648e',
#  'inchi': u'InChI=1S/C6H6N2O2/c9-6(10)2-1-5-3-7-4-8-5/h1-4H,(H,7,8)(H,9,10)/p-1/b2-1+',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:10',
#  'mono_isotopic_molecular_weight': 138.0429229736328,
#  'name': u'urocanate',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'940555dd448c4cefaf88bd27560a648e',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'834cb722b8854ad6b4cb2c16e32b511a',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'82d57f885c3a40b89ed295aee40cbd74',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 139.0498,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'82d57f885c3a40b89ed295aee40cbd74',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'a69a44e0ed96411b8da8e7ccd1bddeb6',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 10.988,
#  'rt_min': 10.595999999999998,
#  'rt_peak': 10.83,
#  'rt_units': 'min',
#  'unique_id': u'a69a44e0ed96411b8da8e7ccd1bddeb6',
#  'username': u'bpb'}],
#  'unique_id': u'834cb722b8854ad6b4cb2c16e32b511a',
#  'username': u'bpb'},
#                               {'compound': [{'creation_time': '2015-10-08T17:36:22',
#  'description': u'',
#  'formula': u'C5H4N4O2',
#  'functional_sets': [],
#  'head_id': u'18027938df864111964d6b0107acd326',
#  'inchi': u'InChI=1S/C5H4N4O2/c10-4-2-3(7-1-6-2)8-5(11)9-4/h1H,(H3,6,7,8,9,10,11)',
#  'inchi_key': None,
#  'last_modified': '2015-10-08T17:38:11',
#  'mono_isotopic_molecular_weight': 152.03343200683594,
#  'name': u'xanthine',
#  'neutralized_2d_inchi': None,
#  'neutralized_2d_inchi_key': None,
#  'neutralized_inchi': None,
#  'neutralized_inchi_key': None,
#  'number_components': None,
#  'permanent_charge': None,
#  'prev_uid': u'origin',
#  'reference_xrefs': [],
#  'synonyms': u'',
#  'unique_id': u'18027938df864111964d6b0107acd326',
#  'url': u'',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'frag_references': [],
#  'head_id': u'5fa5d45916ef4c2fa0879dc9ee6befad',
#  'identification_grade': None,
#  'last_modified': '2015-12-10T20:58:14',
#  'mz_references': [{'adduct': u'',
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'detected_polarity': 'positive',
#  'enabled': True,
#  'head_id': u'1223999ce11743259becdb5bd618251d',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'modification': u'',
#  'mz': 153.0406,
#  'mz_tolerance': 10.0,
#  'mz_tolerance_units': 'ppm',
#  'name': u'Untitled',
#  'observed_formula': u'',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'unique_id': u'1223999ce11743259becdb5bd618251d',
#  'username': u'bpb'}],
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'rt_references': [{'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'enabled': True,
#  'head_id': u'70e8f425eaa646498f05530ce9069a2e',
#  'last_modified': '2015-12-10T20:58:14',
#  'lcms_run': None,
#  'name': u'Untitled',
#  'prev_uid': u'',
#  'ref_type': u'',
#  'rt_max': 7.71,
#  'rt_min': 7.268,
#  'rt_peak': 7.51,
#  'rt_units': 'min',
#  'unique_id': u'70e8f425eaa646498f05530ce9069a2e',
#  'username': u'bpb'}],
#  'unique_id': u'5fa5d45916ef4c2fa0879dc9ee6befad',
#  'username': u'bpb'}],
#  'creation_time': '2015-12-10T20:58:14',
#  'description': u'No description',
#  'head_id': u'2dc81e89d4584b89a7f7444f3bdba440',
#  'last_modified': '2015-12-10T20:58:14',
#  'name': u'20151210_SJ_Positive_Hilic_QTOF6550_HMArkin',
#  'prev_uid': u'',
#  'unique_id': u'2dc81e89d4584b89a7f7444f3bdba440',
#  'username': u'bpb'}

# %%
atlases = metob.retrieve('Atlas',name='20151130_LS_Positive_Hilic_QExactive_Archetypes')
a = atlases[0]
a.compound_identifications[0].mz_references
# Out:
# [{'adduct': u'[M+H]+',
#   'creation_time': '2015-11-30T20:43:49',
#   'description': u'No description',
#   'detected_polarity': 'positive',
#   'enabled': True,
#   'head_id': u'c186cc4119e0487fb72fd5de9b3cfc4c',
#   'last_modified': '2015-11-30T20:43:49',
#   'lcms_run': None,
#   'modification': u'',
#   'mz': 90.0549520864258,
#   'mz_tolerance': 15.0,
#   'mz_tolerance_units': 'ppm',
#   'name': u'Untitled',
#   'observed_formula': u'',
#   'prev_uid': u'origin',
#   'ref_type': u'',
#   'unique_id': u'c186cc4119e0487fb72fd5de9b3cfc4c',
#   'username': u'bpb'}]

# %%
print atlases[0].compound_identifications[0].compound[0].name
print atlases[0].compound_identifications[0].mz_references[0].mz
print atlases[0].compound_identifications[0].rt_references[0].rt_peak
# print atlases[0].compound_identifications[0].references[2].RTpeak
print atlases[0].compound_identifications[0].description.split(',')
print atlases[0].compound_identifications[0].name
# Out:
# L-alanine
# 90.0549520864
# 11.02
# [u'No description']
# Untitled
